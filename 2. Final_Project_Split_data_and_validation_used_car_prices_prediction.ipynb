# %% [markdown]
# <a href="https://colab.research.google.com/github/yperdana/predicting-used-car-price/blob/master/Final_Project_Split_data_and_validation_used_car_prices_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Github and members information:**
#
# github link: https://github.com/yperdana/predicting-used-car-price
#
# Team Members :
# 1. Yohanes Perdana Putra - yperdana.putra@gmail.com - yperdana
# 2. Eko Junirianto - eko.ilkom@gmail.com - ekoilkom
# 3. Yogic Wahyu Rahmadianto - yogicrhama@gmail.com-yogocik
#
# Worksheet :
# 1. Yohanes Perdana Putra: (1) Find data in kaggle. (2) Early prepocessing/filtering and Spliting data. (3) Creating Model. (4) Spliting Data process. (4) Do Validation. (5) do Test the Test Dataset. (6) do documentation in github and colab.
# 2. Eko Junirianto
# 3. Yogic Wahyu Rahmadianto

# %% [markdown]
# **Project Information:**
#
# This project try to predict used car price based on powerPS. We use simple linear regression as our first project to predict numerical.
#
# On the previous colab, we have done experiment creating a model that predict price of used car based on PowerPS. link: https://colab.research.google.com/github/yperdana/predicting-used-car-price-based-on-kilometer/blob/master/Predicting_Used_Car_Price_Based_on_PowerPS.ipynb
#
#
# **Dataset**
#
# Datasource: https://www.kaggle.com/orgesleka/used-cars-database/data
#
# We had filtered the data such as:
# 1. Only SUV type
# 2. Only Mercedes-Bens
# 3. Last 5 years
#
# The reason was, github only could save < 20mb data. We choose SUV because this type is the largest number of data. We decide to filter by brand because we see large difference price on different brand, this will hard to train the model. We took last 5 year, we think the price will not much change.
#
# **Framing & Hypothesis**
#
# Problem: Power of the car can take the effect of the car price. Kaggle provide used car prices data. There are mathematical model can predict the numerical data.
#
# Hypotehsis:
# 1. PowerPS have strong corelation with car price. The result is true.
# 2. Using PowerPS and Car Price in feature and label, we can generate model to predict price based on powerPS. The result is true.
#
# **Preparation/Methodology:**
#
# 1. Learning the Machine Learning Crash Course.
# 3. Select Algorithm (Simple Linear Regression)
# 2. Find Data (Used car price)
# 4. Feature selection, Data Preprocessing/Filter Data
# 5. Implementation: (1) Import libraries (2) Import Data (3) Generate Model (4) Hyperparameter Tunning, Validation process, Test dataset.
# 6. Reporting
#
# **Reference**
#
# We only use reference from Machine Learning Crash Course.

# %%
# Importing Libraries

#Run on TensorFlow 2.x
# %tensorflow_version 2.x

#Import modules
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
#import training dataset and test dataset
train_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSSSuRsQI7kEbHxM9rGNIADIhyLAnT9vUch44nZlCFYsmQAiafrXbnnPrliFeoA-ZkYz8_dRQtKQ9Ha/pub?output=csv")
test_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vR2g80pUxiZnfWzq4yMJotfVFvZZQ7WHSlfpOg2hgjSCEqZjeb__32qE6SYItHFaZbyjtIgFALnQBb0/pub?output=csv")

# %%
#Describe head of training dataset
train_df.head()
# Out:
#      dateCrawled  ...       lastSeen
# 0   4/5/16 12:45  ...   4/5/16 12:45
# 1   3/21/16 9:36  ...  3/31/16 11:16
# 2   4/4/16 09:50  ...   4/6/16 11:17
# 3  3/15/16 23:54  ...   4/6/16 00:46
# 4  3/31/16 21:54  ...   4/6/16 17:45
#
# [5 rows x 20 columns]

# %%
#Describe statistics of training dataset
train_df.describe()
# Out:
#         price  yearOfRegistration  ...  nrOfPictures  postalCode
# count    51.0                51.0  ...          51.0        51.0
# mean  45182.9              2014.5  ...           0.0     56094.5
# std   15454.9                 0.7  ...           0.0     24110.8
# min   24301.0              2014.0  ...           0.0     10715.0
# 25%   33749.5              2014.0  ...           0.0     37441.5
# 50%   41900.0              2014.0  ...           0.0     56566.0
# 75%   56750.0              2015.0  ...           0.0     75763.0
# max   82800.0              2016.0  ...           0.0     94239.0
#
# [8 rows x 7 columns]

# %%
#Describe head of test dataset
test_df.head()
# Out:
#      dateCrawled  ...      lastSeen
# 0   4/4/16 13:47  ...  4/6/16 15:16
# 1   4/4/16 22:58  ...  4/4/16 23:43
# 2   3/20/16 0:36  ...  4/6/16 03:45
# 3  3/14/16 20:44  ...  4/6/16 08:15
# 4  3/28/16 12:55  ...  4/6/16 16:15
#
# [5 rows x 20 columns]

# %%
#Describe statistics of test dataset
test_df.describe()
# Out:
#         price  yearOfRegistration  ...  nrOfPictures  postalCode
# count    10.0                10.0  ...          10.0        10.0
# mean  30557.1              2014.8  ...           0.0     63399.7
# std    4963.4                 0.8  ...           0.0     15633.7
# min   18300.0              2014.0  ...           0.0     36100.0
# 25%   29937.5              2014.0  ...           0.0     52694.0
# 50%   31750.0              2015.0  ...           0.0     70446.0
# 75%   33105.5              2015.0  ...           0.0     74164.8
# max   36499.0              2016.0  ...           0.0     84061.0
#
# [8 rows x 7 columns]

# %%
# Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               

def train_model(model, df, feature, label, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return trained_weight, epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#Define the plotting function

def plot_the_model(trained_weight, trained_bias, feature, label, largest_value):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 200 random points of the dataset.
  random_examples = train_df.sample(n=50)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = largest_value
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve_training(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error only Training")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

def plot_the_loss_curve_validation(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error Training and Validation")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
# Testing Corelation between households and total_rooms.

# Selecting label and feature
my_feature = "price"
my_label= "powerPS" 

# Assign values to these three hyperparameters.
learning_rate = 0.01
epochs = 70
batch_size =  60

# Don't change anything below this line.
my_model = None
my_model = build_model(learning_rate)

#generate model and gain some data from the model
weight, epochs, rmse, history = train_model(my_model, train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

#show the result of the model
plot_the_model(weight, bias, my_feature, my_label,100000)

#show the result loss of training
plot_the_loss_curve_training(epochs, rmse)

#comparing the result between loss of training and validation
plot_the_loss_curve_validation(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Epoch 1/70
# 1/1 [==============================] - 0s 79ms/step - loss: 554218112.0000 - root_mean_squared_error: 23541.8379 - val_loss: 128610488.0000 - val_root_mean_squared_error: 11340.6562
# Epoch 2/70
# 1/1 [==============================] - 0s 34ms/step - loss: 479571808.0000 - root_mean_squared_error: 21899.1289 - val_loss: 115326752.0000 - val_root_mean_squared_error: 10739.0293
# Epoch 3/70
# 1/1 [==============================] - 0s 32ms/step - loss: 430522048.0000 - root_mean_squared_error: 20749.0254 - val_loss: 104992928.0000 - val_root_mean_squared_error: 10246.6055
# Epoch 4/70
# 1/1 [==============================] - 0s 30ms/step - loss: 392344288.0000 - root_mean_squared_error: 19807.6816 - val_loss: 96380344.0000 - val_root_mean_squared_error: 9817.3496
# Epoch 5/70
# 1/1 [==============================] - 0s 30ms/step - loss: 360509600.0000 - root_mean_squared_error: 18987.0898 - val_loss: 88927664.0000 - val_root_mean_squared_error: 9430.1465
# Epoch 6/70
# 1/1 [==============================] - 0s 30ms/step - loss: 332949056.0000 - root_mean_squared_error: 18246.8926 - val_loss: 82325208.0000 - val_root_mean_squared_error: 9073.3242
# Epoch 7/70
# 1/1 [==============================] - 0s 33ms/step - loss: 308521152.0000 - root_mean_squared_error: 17564.7695 - val_loss: 76381824.0000 - val_root_mean_squared_error: 8739.6699
# Epoch 8/70
# 1/1 [==============================] - 0s 31ms/step - loss: 286521248.0000 - root_mean_squared_error: 16926.9395 - val_loss: 70970144.0000 - val_root_mean_squared_error: 8424.3779
# Epoch 9/70
# 1/1 [==============================] - 0s 30ms/step - loss: 266479776.0000 - root_mean_squared_error: 16324.2080 - val_loss: 66000588.0000 - val_root_mean_squared_error: 8124.0747
# Epoch 10/70
# 1/1 [==============================] - 0s 31ms/step - loss: 248066608.0000 - root_mean_squared_error: 15750.1309 - val_loss: 61407540.0000 - val_root_mean_squared_error: 7836.2964
# Epoch 11/70
# 1/1 [==============================] - 0s 30ms/step - loss: 231039904.0000 - root_mean_squared_error: 15199.9971 - val_loss: 57141300.0000 - val_root_mean_squared_error: 7559.1865
# Epoch 12/70
# 1/1 [==============================] - 0s 38ms/step - loss: 215216432.0000 - root_mean_squared_error: 14670.2568 - val_loss: 53163292.0000 - val_root_mean_squared_error: 7291.3164
# Epoch 13/70
# 1/1 [==============================] - 0s 35ms/step - loss: 200454048.0000 - root_mean_squared_error: 14158.1797 - val_loss: 49442844.0000 - val_root_mean_squared_error: 7031.5605
# Epoch 14/70
# 1/1 [==============================] - 0s 30ms/step - loss: 186639712.0000 - root_mean_squared_error: 13661.6143 - val_loss: 45955176.0000 - val_root_mean_squared_error: 6779.0249
# Epoch 15/70
# 1/1 [==============================] - 0s 34ms/step - loss: 173682144.0000 - root_mean_squared_error: 13178.8525 - val_loss: 42679920.0000 - val_root_mean_squared_error: 6532.9873
# Epoch 16/70
# 1/1 [==============================] - 0s 31ms/step - loss: 161506224.0000 - root_mean_squared_error: 12708.5098 - val_loss: 39600088.0000 - val_root_mean_squared_error: 6292.8599
# Epoch 17/70
# 1/1 [==============================] - 0s 29ms/step - loss: 150049456.0000 - root_mean_squared_error: 12249.4678 - val_loss: 36701344.0000 - val_root_mean_squared_error: 6058.1636
# Epoch 18/70
# 1/1 [==============================] - 0s 28ms/step - loss: 139259056.0000 - root_mean_squared_error: 11800.8076 - val_loss: 33971452.0000 - val_root_mean_squared_error: 5828.5034
# Epoch 19/70
# 1/1 [==============================] - 0s 28ms/step - loss: 129089896.0000 - root_mean_squared_error: 11361.7734 - val_loss: 31399834.0000 - val_root_mean_squared_error: 5603.5557
# Epoch 20/70
# 1/1 [==============================] - 0s 29ms/step - loss: 119503104.0000 - root_mean_squared_error: 10931.7471 - val_loss: 28977272.0000 - val_root_mean_squared_error: 5383.0542
# Epoch 21/70
# 1/1 [==============================] - 0s 29ms/step - loss: 110464768.0000 - root_mean_squared_error: 10510.2217 - val_loss: 26695640.0000 - val_root_mean_squared_error: 5166.7822
# Epoch 22/70
# 1/1 [==============================] - 0s 37ms/step - loss: 101945000.0000 - root_mean_squared_error: 10096.7812 - val_loss: 24547706.0000 - val_root_mean_squared_error: 4954.5640
# Epoch 23/70
# 1/1 [==============================] - 0s 29ms/step - loss: 93917224.0000 - root_mean_squared_error: 9691.0898 - val_loss: 22526988.0000 - val_root_mean_squared_error: 4746.2603
# Epoch 24/70
# 1/1 [==============================] - 0s 31ms/step - loss: 86357632.0000 - root_mean_squared_error: 9292.8809 - val_loss: 20627602.0000 - val_root_mean_squared_error: 4541.7622
# Epoch 25/70
# 1/1 [==============================] - 0s 34ms/step - loss: 79244624.0000 - root_mean_squared_error: 8901.9453 - val_loss: 18844164.0000 - val_root_mean_squared_error: 4340.9863
# Epoch 26/70
# 1/1 [==============================] - 0s 31ms/step - loss: 72558488.0000 - root_mean_squared_error: 8518.1270 - val_loss: 17171724.0000 - val_root_mean_squared_error: 4143.8779
# Epoch 27/70
# 1/1 [==============================] - 0s 30ms/step - loss: 66281036.0000 - root_mean_squared_error: 8141.3164 - val_loss: 15605644.0000 - val_root_mean_squared_error: 3950.3979
# Epoch 28/70
# 1/1 [==============================] - 0s 29ms/step - loss: 60395352.0000 - root_mean_squared_error: 7771.4448 - val_loss: 14141603.0000 - val_root_mean_squared_error: 3760.5322
# Epoch 29/70
# 1/1 [==============================] - 0s 30ms/step - loss: 54885576.0000 - root_mean_squared_error: 7408.4800 - val_loss: 12775488.0000 - val_root_mean_squared_error: 3574.2815
# Epoch 30/70
# 1/1 [==============================] - 0s 30ms/step - loss: 49736700.0000 - root_mean_squared_error: 7052.4253 - val_loss: 11503379.0000 - val_root_mean_squared_error: 3391.6631
# Epoch 31/70
# 1/1 [==============================] - 0s 30ms/step - loss: 44934412.0000 - root_mean_squared_error: 6703.3135 - val_loss: 10321508.0000 - val_root_mean_squared_error: 3212.7104
# Epoch 32/70
# 1/1 [==============================] - 0s 37ms/step - loss: 40464964.0000 - root_mean_squared_error: 6361.2075 - val_loss: 9226218.0000 - val_root_mean_squared_error: 3037.4690
# Epoch 33/70
# 1/1 [==============================] - 0s 37ms/step - loss: 36315052.0000 - root_mean_squared_error: 6026.1973 - val_loss: 8213955.0000 - val_root_mean_squared_error: 2865.9998
# Epoch 34/70
# 1/1 [==============================] - 0s 35ms/step - loss: 32471712.0000 - root_mean_squared_error: 5698.3955 - val_loss: 7281227.5000 - val_root_mean_squared_error: 2698.3750
# Epoch 35/70
# 1/1 [==============================] - 0s 31ms/step - loss: 28922256.0000 - root_mean_squared_error: 5377.9414 - val_loss: 6424590.5000 - val_root_mean_squared_error: 2534.6775
# Epoch 36/70
# 1/1 [==============================] - 0s 32ms/step - loss: 25654166.0000 - root_mean_squared_error: 5064.9941 - val_loss: 5640635.0000 - val_root_mean_squared_error: 2375.0022
# Epoch 37/70
# 1/1 [==============================] - 0s 30ms/step - loss: 22655060.0000 - root_mean_squared_error: 4759.7334 - val_loss: 4925968.5000 - val_root_mean_squared_error: 2219.4524
# Epoch 38/70
# 1/1 [==============================] - 0s 30ms/step - loss: 19912630.0000 - root_mean_squared_error: 4462.3569 - val_loss: 4277208.5000 - val_root_mean_squared_error: 2068.1414
# Epoch 39/70
# 1/1 [==============================] - 0s 30ms/step - loss: 17414612.0000 - root_mean_squared_error: 4173.0820 - val_loss: 3690971.0000 - val_root_mean_squared_error: 1921.1899
# Epoch 40/70
# 1/1 [==============================] - 0s 31ms/step - loss: 15148734.0000 - root_mean_squared_error: 3892.1375 - val_loss: 3163868.2500 - val_root_mean_squared_error: 1778.7266
# Epoch 41/70
# 1/1 [==============================] - 0s 31ms/step - loss: 13102728.0000 - root_mean_squared_error: 3619.7690 - val_loss: 2692503.7500 - val_root_mean_squared_error: 1640.8850
# Epoch 42/70
# 1/1 [==============================] - 0s 38ms/step - loss: 11264290.0000 - root_mean_squared_error: 3356.2314 - val_loss: 2273472.2500 - val_root_mean_squared_error: 1507.8038
# Epoch 43/70
# 1/1 [==============================] - 0s 33ms/step - loss: 9621094.0000 - root_mean_squared_error: 3101.7888 - val_loss: 1903361.5000 - val_root_mean_squared_error: 1379.6237
# Epoch 44/70
# 1/1 [==============================] - 0s 30ms/step - loss: 8160789.0000 - root_mean_squared_error: 2856.7095 - val_loss: 1578760.7500 - val_root_mean_squared_error: 1256.4874
# Epoch 45/70
# 1/1 [==============================] - 0s 34ms/step - loss: 6871026.5000 - root_mean_squared_error: 2621.2644 - val_loss: 1296265.1250 - val_root_mean_squared_error: 1138.5364
# Epoch 46/70
# 1/1 [==============================] - 0s 32ms/step - loss: 5739481.5000 - root_mean_squared_error: 2395.7214 - val_loss: 1052488.0000 - val_root_mean_squared_error: 1025.9083
# Epoch 47/70
# 1/1 [==============================] - 0s 31ms/step - loss: 4753894.5000 - root_mean_squared_error: 2180.3428 - val_loss: 844075.1875 - val_root_mean_squared_error: 918.7357
# Epoch 48/70
# 1/1 [==============================] - 0s 32ms/step - loss: 3902112.0000 - root_mean_squared_error: 1975.3765 - val_loss: 667719.7500 - val_root_mean_squared_error: 817.1412
# Epoch 49/70
# 1/1 [==============================] - 0s 31ms/step - loss: 3172152.7500 - root_mean_squared_error: 1781.0538 - val_loss: 520182.0000 - val_root_mean_squared_error: 721.2365
# Epoch 50/70
# 1/1 [==============================] - 0s 31ms/step - loss: 2552265.5000 - root_mean_squared_error: 1597.5812 - val_loss: 398309.0000 - val_root_mean_squared_error: 631.1172
# Epoch 51/70
# 1/1 [==============================] - 0s 40ms/step - loss: 2031002.3750 - root_mean_squared_error: 1425.1324 - val_loss: 299057.9688 - val_root_mean_squared_error: 546.8619
# Epoch 52/70
# 1/1 [==============================] - 0s 37ms/step - loss: 1597300.7500 - root_mean_squared_error: 1263.8436 - val_loss: 219518.1406 - val_root_mean_squared_error: 468.5276
# Epoch 53/70
# 1/1 [==============================] - 0s 31ms/step - loss: 1240560.6250 - root_mean_squared_error: 1113.8046 - val_loss: 156934.4375 - val_root_mean_squared_error: 396.1495
# Epoch 54/70
# 1/1 [==============================] - 0s 29ms/step - loss: 950724.8125 - root_mean_squared_error: 975.0512 - val_loss: 108729.2031 - val_root_mean_squared_error: 329.7411
# Epoch 55/70
# 1/1 [==============================] - 0s 29ms/step - loss: 718357.3750 - root_mean_squared_error: 847.5596 - val_loss: 72521.9766 - val_root_mean_squared_error: 269.2990
# Epoch 56/70
# 1/1 [==============================] - 0s 30ms/step - loss: 534712.8750 - root_mean_squared_error: 731.2407 - val_loss: 46146.1875 - val_root_mean_squared_error: 214.8166
# Epoch 57/70
# 1/1 [==============================] - 0s 30ms/step - loss: 391794.0938 - root_mean_squared_error: 625.9346 - val_loss: 27661.7480 - val_root_mean_squared_error: 166.3182
# Epoch 58/70
# 1/1 [==============================] - 0s 30ms/step - loss: 282397.3438 - root_mean_squared_error: 531.4107 - val_loss: 15362.1807 - val_root_mean_squared_error: 123.9443
# Epoch 59/70
# 1/1 [==============================] - 0s 32ms/step - loss: 200136.9844 - root_mean_squared_error: 447.3667 - val_loss: 7776.3208 - val_root_mean_squared_error: 88.1834
# Epoch 60/70
# 1/1 [==============================] - 0s 33ms/step - loss: 139452.3750 - root_mean_squared_error: 373.4332 - val_loss: 3663.8125 - val_root_mean_squared_error: 60.5294
# Epoch 61/70
# 1/1 [==============================] - 0s 42ms/step - loss: 95592.7578 - root_mean_squared_error: 309.1808 - val_loss: 2004.8024 - val_root_mean_squared_error: 44.7750
# Epoch 62/70
# 1/1 [==============================] - 0s 32ms/step - loss: 64582.4492 - root_mean_squared_error: 254.1308 - val_loss: 1984.2511 - val_root_mean_squared_error: 44.5449
# Epoch 63/70
# 1/1 [==============================] - 0s 31ms/step - loss: 43167.4727 - root_mean_squared_error: 207.7678 - val_loss: 2971.8586 - val_root_mean_squared_error: 54.5148
# Epoch 64/70
# 1/1 [==============================] - 0s 33ms/step - loss: 28747.3691 - root_mean_squared_error: 169.5505 - val_loss: 4498.8281 - val_root_mean_squared_error: 67.0733
# Epoch 65/70
# 1/1 [==============================] - 0s 35ms/step - loss: 19296.4219 - root_mean_squared_error: 138.9116 - val_loss: 6232.8765 - val_root_mean_squared_error: 78.9486
# Epoch 66/70
# 1/1 [==============================] - 0s 34ms/step - loss: 13279.1406 - root_mean_squared_error: 115.2352 - val_loss: 7952.9717 - val_root_mean_squared_error: 89.1794
# Epoch 67/70
# 1/1 [==============================] - 0s 32ms/step - loss: 9565.1826 - root_mean_squared_error: 97.8018 - val_loss: 9525.1143 - val_root_mean_squared_error: 97.5967
# Epoch 68/70
# 1/1 [==============================] - 0s 31ms/step - loss: 7347.9502 - root_mean_squared_error: 85.7202 - val_loss: 10880.2510 - val_root_mean_squared_error: 104.3084
# Epoch 69/70
# 1/1 [==============================] - 0s 32ms/step - loss: 6070.7383 - root_mean_squared_error: 77.9149 - val_loss: 11995.1104 - val_root_mean_squared_error: 109.5222
# Epoch 70/70
# 1/1 [==============================] - 0s 32ms/step - loss: 5362.7246 - root_mean_squared_error: 73.2306 - val_loss: 12876.3779 - val_root_mean_squared_error: 113.4741
# 21854.58397293091

# %%
#test the test dataset
x_test = test_df[my_feature]
y_test = test_df[my_label]

results = my_model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 5862.1353 - root_mean_squared_error: 76.5646

# %% [markdown]
# **Result:**
# 1. From the 1st Graph above, the line generated by training dataset has been fit in the middle of data.
# 2. 2nd Graph shows the loss is much from 700.000 reduce and the curve almost near the botom 70 or near zero.
# 3. 3rd Graph shows training and validation generate nearly same loss result in the end.
# 4. Training MSE result was 73.x and testing MSE result was 76.x, which close enough.
#
# **Conclusion:**
# 1. We think the training model has created a good result by comparing the graph and MSE value.
# 2. PowerPS has strong corelation with Price.
# 3. this model can predict price of mercedes-bens SUV car by powerPS.
